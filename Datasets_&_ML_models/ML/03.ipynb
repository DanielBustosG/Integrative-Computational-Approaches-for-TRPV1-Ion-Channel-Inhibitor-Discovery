# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 3] Descriptor Calculation and Dataset Preparation**
#
# Chanin Nantasenamat
#
# [*'Data Professor' YouTube channel*](http://youtube.com/dataprofessor)
#
# In this Jupyter notebook, we will be building a real-life **data science project** that you can include in your **data science portfolio**. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In **Part 3**, we will be calculating molecular descriptors that are essentially quantitative description of the compounds in the dataset. Finally, we will be preparing this into a dataset for subsequent model building in Part 4.
#
# ---

# %% [markdown]
# ## **Download PaDEL-Descriptor**

# %%
! wget https://github.com/dataprofessor/bioinformatics/raw/master/padel.zip
! wget https://github.com/dataprofessor/bioinformatics/raw/master/padel.sh
# Out:
# wget: /usr/local/lib/libuuid.so.1: no version information available (required by wget)
# --2022-02-01 10:49:35--  https://github.com/dataprofessor/bioinformatics/raw/master/padel.zip
# Resolving github.com (github.com)... 20.201.28.151
# Connecting to github.com (github.com)|20.201.28.151|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.zip [following]
# --2022-02-01 10:49:36--  https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25768637 (25M) [application/zip]
# Saving to: ‘padel.zip.1’
#
# ...

# %%
! unzip padel.zip
# Out:
# Archive:  padel.zip
#   inflating: __MACOSX/._PaDEL-Descriptor
# replace PaDEL-Descriptor/MACCSFingerprinter.xml? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %% [markdown]
# ## **Load bioactivity data**

# %% [markdown]
# Download the curated ChEMBL bioactivity data that has been pre-processed from Parts 1 and 2 of this Bioinformatics Project series. Here we will be using the **bioactivity_data_3class_pIC50.csv** file that essentially contain the pIC50 values that we will be using for building a regression model.

# %%
import pandas as pd

# %%
! pwd
# Out:
# /home/jaime/Dropbox/Tesis/jupiter_notebook/07_clases_10000_5000_dock_3+/notebook

# %%
! ls -la
# Out:
# total 99892
# drwxr-xr-x 5 jaime jaime     4096 feb  1 16:05 .
# drwxr-xr-x 5 jaime jaime     4096 feb  1 16:01 ..
# -rw-r--r-- 1 jaime jaime  3916980 feb  1 16:01 bioactivity_data.csv
# -rw-rw-r-- 1 jaime jaime   212391 feb  1 16:03 bioactivity_preprocessed_data.csv
# -rw-rw-r-- 1 jaime jaime  4588992 feb  1 16:01 descriptors_output.csv
# -rw-rw-r-- 1 jaime jaime     1257 feb  1 16:05 histograma.png
# -rw-rw-r-- 1 jaime jaime    57463 feb  1 16:01 ids_3+.csv
# -rw-rw-r-- 1 jaime jaime    27816 feb  1 16:01 ids_todos.csv
# drwxr-xr-x 2 jaime jaime     4096 feb  1 16:01 .ipynb_checkpoints
# drwxr-xr-x 6 jaime jaime     4096 feb  1 16:01 jupyterenv
# -rw-rw-r-- 1 jaime jaime      122 feb  1 16:05 mannwhitneyu_LogP.csv
# -rw-rw-r-- 1 jaime jaime      122 feb  1 16:05 mannwhitneyu_MW.csv
# -rw-rw-r-- 1 jaime jaime      132 feb  1 16:05 mannwhitneyu_NumHAcceptors.csv
# -rw-rw-r-- 1 jaime jaime      129 feb  1 16:05 mannwhitneyu_NumHDonors.csv
# ...

# %%
df3 = pd.read_csv('trpv1_bioactivity_data_2class_pIC50.csv')

# %%
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL102010                 O=C(NCc1ccc(Cl)cc1)Nc1cccc2cnccc12
# 1          CHEMBL104623          CCC(C)(C)c1ccc(CCC(=O)Nc2cccc3cnccc23)cc1
# 2          CHEMBL103590            O=C(NCCc1ccc(Cl)c(Cl)c1)Nc1cccc2cnccc12
# 3          CHEMBL102486       O=C(NCc1ccc(Cl)c(C(F)(F)F)c1)Nc1cccc2cnccc12
# 4          CHEMBL320906  O=C(Nc1cc(C(F)(F)F)cc(C(F)(F)F)c1)Nc1cccc2cnccc12
# ...                 ...                                                ...
# 2570      CHEMBL4543647  COc1cc2c(cc1OC)[C@H](c1ccccc1)N(C(=O)N1CCc3cc(...
# 2571      CHEMBL4588287  COc1cc2c(cc1OC)[C@H](c1ccc(Cl)cc1)N(C(=O)N1CCc...
# 2572      CHEMBL4576619  COc1cc2c(cc1OC)[C@H](c1ccc(F)cc1)N(C(=O)N1CCc3...
# 2573      CHEMBL4647981     CCCCCCC(C)(C)c1cc(OC)cc(OCCCCCCCC(=O)NC2CC2)c1
# 2574      CHEMBL4555711          COc1cc(N[C@@H]2CCCC[C@]2(O)C(F)(F)F)ccc1F
#
# ...

# %%
data = [{'canonical_smiles': 'O=P(O)(O)C(O)(Cn1ccnc1)P(=O)(O)O', 'molecule_chembl_id': 'CHEMBL924'}]
df3_selection = pd.DataFrame(data)
df3_selection.to_csv('molecule.smi', sep='\t', index=False, header=False)

# %%
! cat molecule.smi | head -5
# Out:
# O=P(O)(O)C(O)(Cn1ccnc1)P(=O)(O)O	CHEMBL924

# %%
! cat molecule.smi | wc -l
# Out:
# 1

# %% [markdown]
# ## **Calculate fingerprint descriptors**

# %% [markdown]
# ### **Calculate PaDEL descriptors**

# %%
! cat padel.sh
# Out:
# java -Xms1G -Xmx1G -Djava.awt.headless=true -jar ./PaDEL-Descriptor/PaDEL-Descriptor.jar -removesalt -standardizenitro -fingerprints -descriptortypes ./PaDEL-Descriptor/PubchemFingerprinter.xml -dir ./ -file descriptors_output.csv

# %%
! bash padel.sh
# Out:
# Processing CHEMBL924 in molecule.smi (1/1).
# Descriptor calculation completed in 8.788 secs . Average speed: 8,79 s/mol.

# %%
! ls -l
# Out:
# total 95368
# -rw-r--r-- 1 jaime jaime  3916980 feb  8 14:33 bioactivity_data.csv
# -rw-r--r-- 1 jaime jaime   212391 feb  8 14:33 bioactivity_preprocessed_data.csv
# -rw-r--r-- 1 jaime jaime    13122 jun  3 17:13 descriptors_output.csv
# -rw-r--r-- 1 jaime jaime     1257 feb  8 14:33 histograma.png
# -rw-r--r-- 1 jaime jaime    57463 feb  8 14:33 ids_3+.csv
# -rw-r--r-- 1 jaime jaime    27816 feb  8 14:33 ids_todos.csv
# drwxr-xr-x 6 jaime jaime     4096 feb  8 14:33 jupyterenv
# -rw-r--r-- 1 jaime jaime      122 feb  8 14:33 mannwhitneyu_LogP.csv
# -rw-r--r-- 1 jaime jaime      122 feb  8 14:33 mannwhitneyu_MW.csv
# -rw-r--r-- 1 jaime jaime      132 feb  8 14:33 mannwhitneyu_NumHAcceptors.csv
# -rw-r--r-- 1 jaime jaime      129 feb  8 14:33 mannwhitneyu_NumHDonors.csv
# -rw-r--r-- 1 jaime jaime      120 feb  8 14:33 mannwhitneyu_pIC50.csv
# -rwxr--r-- 1 jaime jaime 85055499 feb  8 14:33 Miniconda3-py37_4.8.2-Linux-x86_64.sh
# ...

# %% [markdown]
# ## **Preparing the X and Y Data Matrices**

# %% [markdown]
# ### **X data matrix**

# %%
df3_X = pd.read_csv('descriptors_output.csv')

# %%
df3_X
# Out:
#         Name  PubchemFP0  PubchemFP1  PubchemFP2  PubchemFP3  PubchemFP4  \
# 0  CHEMBL924           1           1           0           0           0
#
#    PubchemFP5  PubchemFP6  PubchemFP7  PubchemFP8  ...  PubchemFP871  \
# 0           0           0           0           0  ...             0
#
#    PubchemFP872  PubchemFP873  PubchemFP874  PubchemFP875  PubchemFP876  \
# 0             0             0             0             0             0
#
#    PubchemFP877  PubchemFP878  PubchemFP879  PubchemFP880
# 0             0             0             0             0
#
# [1 rows x 882 columns]

# %%
df3_X = df3_X.drop(columns=['Name'])
df3_X
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-16dc25c104cb> in <module>
# ----> 1 df3_X = df3_X.drop(columns=['Name'])
#       2 df3_X
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %% [markdown]
# ## **Y variable**

# %% [markdown]
# ### **Convert IC50 to pIC50**

# %%
df3_Y = pd.DataFrame([{'pIC50':0}])
df3_Y
# Out:
#    pIC50
# 0      0

# %% [markdown]
# ## **Combining X and Y variable**

# %%
dataset3 = pd.concat([df3_X,df3_Y], axis=1)
dataset3 = pd.concat([dataset3, pd.DataFrame([{'standard_value':0}])], axis=1)

# %%
dataset3
# Out:
#    PubchemFP0  PubchemFP1  PubchemFP2  PubchemFP3  PubchemFP4  PubchemFP5  \
# 0           1           1           0           0           0           0
#
#    PubchemFP6  PubchemFP7  PubchemFP8  PubchemFP9  ...  PubchemFP873  \
# 0           0           0           0           1  ...             0
#
#    PubchemFP874  PubchemFP875  PubchemFP876  PubchemFP877  PubchemFP878  \
# 0             0             0             0             0             0
#
#    PubchemFP879  PubchemFP880  pIC50  standard_value
# 0             0             0      0               0
#
# [1 rows x 883 columns]

# %%
dataset3.to_csv('trpv1_06_bioactivity_data_3class_pIC50_pubchem_fp_1.csv', index=False)

# %% [markdown]
# # **Let's download the CSV file to your local computer for the Part 3B (Model Building).**
